# %%
import pandas as pd
from glob import glob
pd.set_option('display.max_columns', None)

df1 = pd.read_csv("../../data/raw/Test-1542969243754.csv")
df2 = pd.read_csv("../../data/raw/Test_Beneficiarydata-1542969243754.csv")
df3 = pd.read_csv("../../data/raw/Test_Inpatientdata-1542969243754.csv")
df4 = pd.read_csv("../../data/raw/Test_Outpatientdata-1542969243754.csv")
df5 = pd.read_csv("../../data/raw/Train-1542865627584.csv")
df6 = pd.read_csv("../../data/raw/Train_Beneficiarydata-1542865627584.csv")
df7 = pd.read_csv("../../data/raw/Train_Inpatientdata-1542865627584.csv")
df8 = pd.read_csv("../../data/raw/Train_Outpatientdata-1542865627584.csv")

# %%
df1
# Out:
#       Provider
# 0     PRV51002
# 1     PRV51006
# 2     PRV51009
# 3     PRV51010
# 4     PRV51018
# ...        ...
# 1348  PRV57713
# 1349  PRV57726
# 1350  PRV57745
# 1351  PRV57749
# 1352  PRV57750
#
# [1353 rows x 1 columns]

# %%
df5.groupby(['PotentialFraud']).count()
# Out:
#                 Provider
# PotentialFraud
# No                  4904
# Yes                  506

# %%
df5
# Out:
#       Provider PotentialFraud
# 0     PRV51001             No
# 1     PRV51003            Yes
# 2     PRV51004             No
# 3     PRV51005            Yes
# 4     PRV51007             No
# ...        ...            ...
# 5405  PRV57759             No
# 5406  PRV57760             No
# 5407  PRV57761             No
# 5408  PRV57762             No
# 5409  PRV57763             No
#
# [5410 rows x 2 columns]

# %%
df6
# Out:
#             BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0        BENE11001  1943-01-01  NaN       1     1                     0
# 1        BENE11002  1936-09-01  NaN       2     1                     0
# 2        BENE11003  1936-08-01  NaN       1     1                     0
# 3        BENE11004  1922-07-01  NaN       1     1                     0
# 4        BENE11005  1935-09-01  NaN       1     1                     0
# ...            ...         ...  ...     ...   ...                   ...
# 138551  BENE159194  1939-07-01  NaN       1     1                     0
# 138552  BENE159195  1938-12-01  NaN       2     1                     0
# 138553  BENE159196  1916-06-01  NaN       2     1                     0
# 138554  BENE159197  1930-01-01  NaN       1     1                     0
# 138555  BENE159198  1952-04-01  NaN       2     1                     0
#
#         State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# ...

# %%
df7
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2       BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3       BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4       BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
# ...           ...       ...          ...         ...       ...
# 40469  BENE159167  CLM69886   2009-09-28  2009-10-02  PRV53671
# 40470  BENE159175  CLM74504   2009-11-03  2009-11-06  PRV54981
# 40471  BENE159177  CLM76485   2009-11-18  2009-11-22  PRV56588
# 40472  BENE159177  CLM79949   2009-12-17  2009-12-18  PRV56575
# 40473  BENE159188  CLM69948   2009-09-28  2009-10-06  PRV54765
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                        5000          PHY318495          PHY318495
# ...

# %%
df8
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1        BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2        BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3        BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4        BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
# ...            ...        ...          ...         ...       ...
# 517732  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 517733  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 517734  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 517735  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 517736  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                           30          PHY326117                NaN
# ...

# %% [markdown]
# One issue is that the labels are at the provider level but the data is at the claim level.
#
# One approach is to aggregate data to the provider level.
#
# ### How many claims are there on average per provider?
#
# Answer: 19.3
#
# ### How much do claims differ for a given provider?
#
# It varies a lot.
#
# ### How much will the claims data be affecting the provider_has_potential_fraud result?
#
# It has a big impact.

# %%
# Out:
# 19.347036328871894

# %%
df7.provider.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10448\2429801770.py in <module>
# ----> 1 df7.provider.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'provider'

# %%
df7.loc[df7['Provider'] == 'PRV55912']
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1882    BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2964    BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3311    BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 3729    BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
# 4995    BENE28966  CLM56700   2009-06-22  2009-06-25  PRV55912
# 5081    BENE29251  CLM42062   2009-03-11  2009-03-19  PRV55912
# 5780    BENE31905  CLM37729   2009-02-10  2009-03-03  PRV55912
# 5781    BENE31905  CLM49964   2009-05-06  2009-05-09  PRV55912
# 5784    BENE31905  CLM77968   2009-12-01  2009-12-05  PRV55912
# 5785    BENE31905  CLM80697   2009-12-25  2009-12-28  PRV55912
# 7343    BENE37685  CLM35228   2009-01-24  2009-01-25  PRV55912
# 7345    BENE37685  CLM78693   2009-12-07  2009-12-14  PRV55912
# 9481    BENE45976  CLM32244   2009-01-03  2009-01-14  PRV55912
# ...
